# %%
import os,torch
import matplotlib.pyplot as plt
import matplotlib.image as img
import PIL.Image as Image
import glob

# %%
norain = '/data/jan4021/Data/deraining/Train/gt/norain-1.png'
streak = '/data/jan4021/Data/deraining/Train/RainTrainL/rainstreak-1.png'

norain = img.imread(norain)
streak = img.imread(streak)

for i in range(10):
    a = torch.tensor(norain)
    b = torch.tensor(streak) * 0.1 * i
    b = torch.stack([b,b,b],dim=2)

    plt.imshow(a+b)
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
import os

txt_file = '/home/jan4021/Restoration/2022-CVPR-AirNet/data_dir/hazy/new.txt'
new_txt_contents = ''

with open(txt_file, 'r') as f:
    lines = f.readlines()
    for i, line in enumerate(lines):
        new_txt_contents += line[10:]

with open(txt_file, 'w') as f:
    f.write(new_txt_contents)
